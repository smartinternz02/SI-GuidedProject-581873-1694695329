# %% [markdown]
# # Assignment - 3

# %% [markdown]
# ## Importing required libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing Data

# %%
data = pd.read_csv("/content/penguins_size.csv")

# %% [markdown]
# ## Initial Analysis

# %%
data.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
data.shape
# Out:
# (344, 7)

# %%
print(data.dtypes)
# Out:
# species               object
# island                object
# culmen_length_mm     float64
# culmen_depth_mm      float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Univariate Analysis

# %%
sns.displot(data.culmen_length_mm)

# %%
sns.displot(data.culmen_depth_mm)

# %%
sns.displot(data.flipper_length_mm)

# %%
sns.displot(data.body_mass_g)

# %%
sns.barplot(x =data.island.value_counts().index,y =data.island.value_counts() )
# Out:
# <Axes: ylabel='island'>

# %%
sns.barplot(x =data.sex.value_counts().index,y =data.sex.value_counts() )
# Out:
# <Axes: ylabel='sex'>

# %%
sns.barplot(x =data.species.value_counts().index,y =data.species.value_counts() )
# Out:
# <Axes: ylabel='species'>

# %% [markdown]
# ### Bi - variate Analysis

# %%
sns.lineplot(x = data.species,y=data.island)
# Out:
# <Axes: xlabel='species', ylabel='island'>

# %%
sns.lineplot(x = data.species,y=data.culmen_length_mm)
# Out:
# <Axes: xlabel='species', ylabel='culmen_length_mm'>

# %%
sns.lineplot(x = data.species,y=data.culmen_depth_mm)
# Out:
# <Axes: xlabel='species', ylabel='culmen_depth_mm'>

# %%
sns.lineplot(x = data.species,y=data.flipper_length_mm)
# Out:
# <Axes: xlabel='species', ylabel='flipper_length_mm'>

# %%
sns.lineplot(x = data.species,y=data.body_mass_g)
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>

# %%
sns.lineplot(x = data.species,y=data.sex)
# Out:
# <Axes: xlabel='species', ylabel='sex'>

# %% [markdown]
# ### Multi-variate Analysis

# %%
sns.pairplot(data, hue = 'species')

# %%
sns.pairplot(data, hue = 'sex')

# %%
sns.heatmap(data.corr(), annot = True)
# Out:
# <ipython-input-147-1f756df288d0>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot = True)
# <Axes: >

# %% [markdown]
# ## Descriptive Statistics

# %%
data.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %% [markdown]
# ## Checking for Null Values

# %%
data.isnull().any()
# Out:
# species              False
# island               False
# culmen_length_mm      True
# culmen_depth_mm       True
# flipper_length_mm     True
# body_mass_g           True
# sex                   True
# dtype: bool

# %%
data.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %% [markdown]
# ### Checking Distribution Shape

# %%
sns.distplot(data.culmen_length_mm)
# Out:
# <ipython-input-151-b6e8ad7c1216>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.culmen_length_mm)
# <Axes: xlabel='culmen_length_mm', ylabel='Density'>

# %%
sns.distplot(data.culmen_depth_mm)
# Out:
# <ipython-input-152-4d046b4566b0>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.culmen_depth_mm)
# <Axes: xlabel='culmen_depth_mm', ylabel='Density'>

# %%
sns.distplot(data.flipper_length_mm)
# Out:
# <ipython-input-153-c566abf550e6>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.flipper_length_mm)
# <Axes: xlabel='flipper_length_mm', ylabel='Density'>

# %%
sns.distplot(data.body_mass_g)
# Out:
# <ipython-input-154-5b0f02613933>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.body_mass_g)
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %% [markdown]
# ### Treating Null Values

# %%
data.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %%
data['culmen_length_mm'].fillna(data['culmen_length_mm'].median(),inplace =True)
data['culmen_depth_mm'].fillna(data['culmen_depth_mm'].median(),inplace =True)
data['flipper_length_mm'].fillna(data['flipper_length_mm'].median(),inplace =True)
data['body_mass_g'].fillna(data['body_mass_g'].median(),inplace =True)

# %%
data.sex.unique()
# Out:
# array(['MALE', 'FEMALE', nan, '.'], dtype=object)

# %%
data.sex.value_counts()
# Out:
# MALE      168
# FEMALE    165
# .           1
# Name: sex, dtype: int64

# %%
data.island.mode()
# Out:
# 0    Biscoe
# Name: island, dtype: object

# %%
data.sex.fillna(data.sex.mode()[0],inplace =True)

# %%
data.isnull().sum()
# Out:
# species              0
# island               0
# culmen_length_mm     0
# culmen_depth_mm      0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %% [markdown]
# ## Finding Outliers

# %%
sns.boxplot(data.culmen_length_mm)
# Out:
# <Axes: >

# %%
sns.boxplot(data.culmen_depth_mm)
# Out:
# <Axes: >

# %%
sns.boxplot(data.flipper_length_mm)
# Out:
# <Axes: >

# %%
sns.boxplot(data.body_mass_g)
# Out:
# <Axes: >

# %%
# No outliers to be seen

# %% [markdown]
# ## Correlation

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data.corr(),annot =True)
# Out:
# <ipython-input-167-fa2826dd678b>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot =True)
# <Axes: >

# %% [markdown]
# ## Categorical Cloumns Encoding

# %%
data.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen             39.10             18.7              181.0
# 1  Adelie  Torgersen             39.50             17.4              186.0
# 2  Adelie  Torgersen             40.30             18.0              195.0
# 3  Adelie  Torgersen             44.45             17.3              197.0
# 4  Adelie  Torgersen             36.70             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3       4050.0    MALE
# 4       3450.0  FEMALE

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
data.sex = le.fit_transform(data.sex)
data.island = le.fit_transform(data.island)

# %%
data.head()
# Out:
#   species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie       2             39.10             18.7              181.0
# 1  Adelie       2             39.50             17.4              186.0
# 2  Adelie       2             40.30             18.0              195.0
# 3  Adelie       2             44.45             17.3              197.0
# 4  Adelie       2             36.70             19.3              193.0
#
#    body_mass_g  sex
# 0       3750.0    2
# 1       3800.0    1
# 2       3250.0    1
# 3       4050.0    2
# 4       3450.0    1

# %% [markdown]
# ## Splitting the data into dependent and independent variables.

# %%
y = data.species
y.head()
# Out:
# 0    Adelie
# 1    Adelie
# 2    Adelie
# 3    Adelie
# 4    Adelie
# Name: species, dtype: object

# %%
X =data.drop(columns =['species'],axis =1)
X.head()
# Out:
#    island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0       2             39.10             18.7              181.0       3750.0
# 1       2             39.50             17.4              186.0       3800.0
# 2       2             40.30             18.0              195.0       3250.0
# 3       2             44.45             17.3              197.0       4050.0
# 4       2             36.70             19.3              193.0       3450.0
#
#    sex
# 0    2
# 1    1
# 2    1
# 3    2
# 4    1

# %% [markdown]
# ## Scaling on independent variables

# %%
from sklearn.preprocessing import MinMaxScaler
scale =MinMaxScaler()

# %%
X_scaled= pd.DataFrame(scale.fit_transform(X),columns =X.columns)
X_scaled.head()
# Out:
#    island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0     1.0          0.254545         0.666667           0.152542     0.291667
# 1     1.0          0.269091         0.511905           0.237288     0.305556
# 2     1.0          0.298182         0.583333           0.389831     0.152778
# 3     1.0          0.449091         0.500000           0.423729     0.375000
# 4     1.0          0.167273         0.738095           0.355932     0.208333
#
#    sex
# 0  1.0
# 1  0.5
# 2  0.5
# 3  1.0
# 4  0.5

# %% [markdown]
# ## Train test split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_scaled,y,test_size=0.3,random_state=10)

# %% [markdown]
# ## Checking the training and testing data shape.

# %%
X_train.shape
# Out:
# (240, 6)

# %%
y_train.shape
# Out:
# (240,)

# %%
X_test.shape
# Out:
# (104, 6)

# %%
y_test.shape
# Out:
# (104,)
